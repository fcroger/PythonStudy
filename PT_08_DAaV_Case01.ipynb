# %% [markdown]
# # <center>数据分析和可视化案例01</center>

# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import matplotlib.pyplot as plt #导入相应的包
df=pd.read_csv('sales.csv',parse_dates=['date'],index_col='date')

df_resample = df.resample('W').sum()

plt.plot(df_resample.index,df_resample.values)
plt.show()
